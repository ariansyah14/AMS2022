# %%
import pandas as pd
import time
import tweepy
import numpy as np
import re

# %%
def twitter_config():
    """
    Fungsi utilitas untuk mengkonfigurasi konsumsi file API Twitter dengan␣
    ,!kunci yang disediakan.
    """
    # Otentikasi dan akses menggunakan kunci:
    auth = tweepy.OAuthHandler("JLGvLiMHnOZkSDyfvmNZOwB7j","crxgjo1KIRh0HAWZNec1vKO7MlAdc1MX7XzGGgVgBA6Mt30GrB")
    auth.set_access_token("1572483046141751298-Q3ZqiGCrM8zcGcw0fepHL1luRLXXr6","A0mYVIrOVVc2KHDdol3hsGS0LFFXiRPfxToGk7FIBWt97")
    # Kembalikan akses ke API:
    api = tweepy.API(auth)
    try:
        api.verify_credentials()
        print("Authentication OK")
    except:
        print("Error during authentication")
    return api

# %%
# buat extractor object
extractor = twitter_config()
# Out:
# Authentication OK

# %%
#Step 3 - Retrieve Tweets
tweets = extractor.search_tweets(q='knalpot racing', count=1000)
print("Tweets terambil: {}.\n".format(len(tweets)))
# Out:
# Tweets terambil: 100.

# %%
dataset_search = pd.DataFrame(data=[tweet.text for tweet in tweets], columns=['Tweets'])

# Kami membuat tampilan kerangka data:
display(dataset_search.head(16))
# Out:
#                                                Tweets
# 0    @Almaylifi tercium bau asap knalpot motor racing
# 1   @hanajihyo iyaa, besok yang pake knalpot racin...
# 2   Motor bebek pake knalpot racing 75ribu, lewat ...
# 3   @SeputarTetangga Ngebutnya sih gak kenceng tap...
# 4                    @18fesss Knalpot racing original
# 5   NJING JAMET BANGET LO. PASTI KALAU NAIK MOTOR ...
# 6   Pekain saja dengan pekajaman \n\nReady bosquee...
# 7   Rasanya dah kaya oven apalagi surabaya tuh pan...
# 8   Ie bengkel sebelah loba motor sonic pake knalp...
# 9   Hujan plus lagu sedih, emang mendukung, sempat...
# 10                  @Husen_Jafar Gara2 knalpot racing
# 11  anjing udah bikin telinga budeg, pelan, disali...
# 12  @tanyakanrl mimpi jadi rantai motor, pas motor...
# 13  @hahahihiheheho_ @sbyfess Trantangtangtangtang...
# 14  @sekarningrum__ @humanlangka @vellavelpi Izin ...
# 15  Nah jika berkendara dengan sepeda motor jangan...

# %%
dataset_search
# Out:
#                                                Tweets
# 0    @Almaylifi tercium bau asap knalpot motor racing
# 1   @hanajihyo iyaa, besok yang pake knalpot racin...
# 2   Motor bebek pake knalpot racing 75ribu, lewat ...
# 3   @SeputarTetangga Ngebutnya sih gak kenceng tap...
# 4                    @18fesss Knalpot racing original
# ..                                                ...
# 95  @jek___ tat lu pernah ga pas kentut suaranya k...
# 96  Saya menjual knalpot cb150 r face... seharga R...
# 97  Saya menjual knalpot fiz r stainl... seharga R...
# 98  @guddayla @cursedkidd gmw,, wili pke knalpot r...
# 99  tolong pak sekalian motor cc kecil yg pake kna...
#
# [100 rows x 1 columns]

# %%
def cleanTweets(text):
    text = re.sub('@[A-Za-z0-9_]+', '', text) #removes @mentions
    text = re.sub('#','',text) #removes hastag '#' symbol
    text = re.sub('RT :[\s]+','',text)
    text = re.sub('https?:\/\/\S+', '', text) 
    text = re.sub('\n',' ',text)
    return text

dataset_search['cleanedTweets'] = dataset_search['Tweets'].apply(cleanTweets) #apply cleanTweet function to the tweet

# %%
dataset_search
# Out:
#                                                Tweets  \
# 0    @Almaylifi tercium bau asap knalpot motor racing
# 1   @hanajihyo iyaa, besok yang pake knalpot racin...
# 2   Motor bebek pake knalpot racing 75ribu, lewat ...
# 3   @SeputarTetangga Ngebutnya sih gak kenceng tap...
# 4                    @18fesss Knalpot racing original
# ..                                                ...
# 95  @jek___ tat lu pernah ga pas kentut suaranya k...
# 96  Saya menjual knalpot cb150 r face... seharga R...
# 97  Saya menjual knalpot fiz r stainl... seharga R...
# 98  @guddayla @cursedkidd gmw,, wili pke knalpot r...
# 99  tolong pak sekalian motor cc kecil yg pake kna...
#
#                                         cleanedTweets
# 0               tercium bau asap knalpot motor racing
# 1        iyaa, besok yang pake knalpot racing itu aku
# 2   Motor bebek pake knalpot racing 75ribu, lewat ...
# 3    Ngebutnya sih gak kenceng tapi kalau suara kn...
# 4                             Knalpot racing original
# ..                                                ...
# 95   tat lu pernah ga pas kentut suaranya kek knal...
# 96  Saya menjual knalpot cb150 r face... seharga R...
# 97  Saya menjual knalpot fiz r stainl... seharga R...
# 98                      gmw,, wili pke knalpot racing
# 99  tolong pak sekalian motor cc kecil yg pake kna...
#
# [100 rows x 2 columns]

# %%
dataset_search['cleanedTweets'] = dataset_search['cleanedTweets'].str.lower()

# %%
dataset_search.head(5)
# Out:
#                                               Tweets  \
# 0   @Almaylifi tercium bau asap knalpot motor racing
# 1  @hanajihyo iyaa, besok yang pake knalpot racin...
# 2  Motor bebek pake knalpot racing 75ribu, lewat ...
# 3  @SeputarTetangga Ngebutnya sih gak kenceng tap...
# 4                   @18fesss Knalpot racing original
#
#                                        cleanedTweets
# 0              tercium bau asap knalpot motor racing
# 1       iyaa, besok yang pake knalpot racing itu aku
# 2  motor bebek pake knalpot racing 75ribu, lewat ...
# 3   ngebutnya sih gak kenceng tapi kalau suara kn...
# 4                            knalpot racing original

# %%
import translators as ts
# Out:
# Using state Central Java server backend.

# %%
dataset_search['Translated'] = dataset_search['cleanedTweets'].apply(lambda x: ts.google(x, from_language='id', to_language='en'))

# %%
dataset_search.head()
# Out:
#                                               Tweets  \
# 0   @Almaylifi tercium bau asap knalpot motor racing
# 1  @hanajihyo iyaa, besok yang pake knalpot racin...
# 2  Motor bebek pake knalpot racing 75ribu, lewat ...
# 3  @SeputarTetangga Ngebutnya sih gak kenceng tap...
# 4                   @18fesss Knalpot racing original
#
#                                        cleanedTweets  \
# 0              tercium bau asap knalpot motor racing
# 1       iyaa, besok yang pake knalpot racing itu aku
# 2  motor bebek pake knalpot racing 75ribu, lewat ...
# 3   ngebutnya sih gak kenceng tapi kalau suara kn...
# 4                            knalpot racing original
#
#                                           Translated
# 0               smells of smoke exhaust motor racing
# 1             Yes, tomorrow I use the racing exhaust
# 2  Duck motorbike using a 75 thousand racing exha...
# 3  Speed up, it's not fast, but if the sound of a...
# 4                            Original Racing Exhaust

# %%
from textblob import TextBlob

#get subjectivity and polarity of tweets with a function
def getSubjectivity(text):
    return TextBlob(text).sentiment.subjectivity

#get polarity with a function
def getPolarity(text):
    return TextBlob(text).sentiment.polarity

dataset_search['Subjectivity'] = dataset_search['Translated'].apply(getSubjectivity)
dataset_search['Polarity'] = dataset_search['Translated'].apply(getPolarity)

# %%
dataset_search.head()
# Out:
#                                               Tweets  \
# 0   @Almaylifi tercium bau asap knalpot motor racing
# 1  @hanajihyo iyaa, besok yang pake knalpot racin...
# 2  Motor bebek pake knalpot racing 75ribu, lewat ...
# 3  @SeputarTetangga Ngebutnya sih gak kenceng tap...
# 4                   @18fesss Knalpot racing original
#
#                                        cleanedTweets  \
# 0              tercium bau asap knalpot motor racing
# 1       iyaa, besok yang pake knalpot racing itu aku
# 2  motor bebek pake knalpot racing 75ribu, lewat ...
# 3   ngebutnya sih gak kenceng tapi kalau suara kn...
# 4                            knalpot racing original
#
#                                           Translated  Subjectivity  Polarity
# 0               smells of smoke exhaust motor racing          0.00  0.000000
# 1             Yes, tomorrow I use the racing exhaust          0.00  0.000000
# 2  Duck motorbike using a 75 thousand racing exha...          0.40 -0.250000
# 3  Speed up, it's not fast, but if the sound of a...          0.60  0.133333
# 4                            Original Racing Exhaust          0.75  0.375000

# %%
#create a function to check negative, neutral and positive analysis
def getAnalysis(score):
    if score<0:
        return '-1'
    elif score == 0:
        return '0'
    else:
        return '1'
    
dataset_search['Analysis'] = dataset_search['Polarity'].apply(getAnalysis)

# %%
dataset_search['Analysis'].value_counts()
# Out:
# 0     42
# -1    29
# 1     29
# Name: Analysis, dtype: int64

# %%
dataset_search.head()
# Out:
#                                               Tweets  \
# 0   @Almaylifi tercium bau asap knalpot motor racing
# 1  @hanajihyo iyaa, besok yang pake knalpot racin...
# 2  Motor bebek pake knalpot racing 75ribu, lewat ...
# 3  @SeputarTetangga Ngebutnya sih gak kenceng tap...
# 4                   @18fesss Knalpot racing original
#
#                                        cleanedTweets  \
# 0              tercium bau asap knalpot motor racing
# 1       iyaa, besok yang pake knalpot racing itu aku
# 2  motor bebek pake knalpot racing 75ribu, lewat ...
# 3   ngebutnya sih gak kenceng tapi kalau suara kn...
# 4                            knalpot racing original
#
#                                           Translated  Subjectivity  Polarity  \
# 0               smells of smoke exhaust motor racing          0.00  0.000000
# 1             Yes, tomorrow I use the racing exhaust          0.00  0.000000
# 2  Duck motorbike using a 75 thousand racing exha...          0.40 -0.250000
# 3  Speed up, it's not fast, but if the sound of a...          0.60  0.133333
# 4                            Original Racing Exhaust          0.75  0.375000
#
#   Analysis
# 0        0
# 1        0
# 2       -1
# 3        1
# 4        1

# %%
dataset_search.to_csv('Downloads/Knalpot.csv', index=False)

# %%
nlp = pd.read_csv("Downloads/Knalpot.csv", sep=',')

# %%
nlp.head()
# Out:
#                                               Tweets  \
# 0   @Almaylifi tercium bau asap knalpot motor racing
# 1  @hanajihyo iyaa, besok yang pake knalpot racin...
# 2  Motor bebek pake knalpot racing 75ribu, lewat ...
# 3  @SeputarTetangga Ngebutnya sih gak kenceng tap...
# 4                   @18fesss Knalpot racing original
#
#                                        cleanedTweets  \
# 0              tercium bau asap knalpot motor racing
# 1       iyaa, besok yang pake knalpot racing itu aku
# 2  motor bebek pake knalpot racing 75ribu, lewat ...
# 3   ngebutnya sih gak kenceng tapi kalau suara kn...
# 4                            knalpot racing original
#
#                                           Translated  Subjectivity  Polarity  \
# 0               smells of smoke exhaust motor racing          0.00  0.000000
# 1             Yes, tomorrow I use the racing exhaust          0.00  0.000000
# 2  Duck motorbike using a 75 thousand racing exha...          0.40 -0.250000
# 3  Speed up, it's not fast, but if the sound of a...          0.60  0.133333
# 4                            Original Racing Exhaust          0.75  0.375000
#
#    Analysis
# 0         0
# 1         0
# 2        -1
# 3         1
# 4         1
